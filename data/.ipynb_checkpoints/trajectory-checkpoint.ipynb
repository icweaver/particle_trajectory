# %%
import pandas as pd

# %%
pf=pd.read_table('test.dat',sep='\s{1,9}')
pf
# Out:
#     step      time         x             y  z              vx              vy  \
# 0      1  0.000000 -0.931381 -2.911208e-15  0   750902.627393  -247822.494710
# 1      2  0.004843 -0.930390 -3.600931e-04  0   737839.346536  -292696.267291
# 2      3  0.009772 -0.929397 -7.868325e-04  0   728568.416962  -336783.125273
# 3      4  0.014764 -0.928401 -1.278893e-03  0   723161.460877  -379989.970280
# 4      5  0.019793 -0.927402 -1.833703e-03  0   721651.327772  -422248.782264
# 5      6  0.024832 -0.926401 -2.447525e-03  0   724024.482454  -463520.498201
# 6      7  0.029855 -0.925397 -3.115625e-03  0   730216.278735  -503796.765647
# 7      8  0.034836 -0.924391 -3.832524e-03  0   740110.056727  -543099.227997
# 8      9  0.039749 -0.923382 -4.592292e-03  0   753540.384672  -581476.424831
# 9     10  0.044576 -0.922372 -5.388855e-03  0   770300.034030  -618998.804118
# 10    11  0.049297 -0.921359 -6.216276e-03  0   790149.652005  -655752.621454
# ...

# %%
x = pf['x']
y = pf['y']
t = pf['time']
E = pf['U']+pf['K']
plot(t,E)
